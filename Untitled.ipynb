# %%
import os
print(os.getcwd())
print(os.path.exists("/home/jovyan/work/data"))
print(os.listdir("/home/jovyan/work"))
# Out:
# /home/jovyan/work
# True
# ['docker-compose.yaml', '.DS_Store', 'Untitled.ipynb', 'README.md', '.gitignore', '.ipynb_checkpoints', 'notes.md', '.git', 'data', 'notebooks']
